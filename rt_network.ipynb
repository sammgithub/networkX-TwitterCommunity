# %%
import pandas as pd
# import numpy as np
import networkx as nx
import community as community_louvain
import matplotlib.cm as cm
import matplotlib.pyplot as plt
# import json

# %%
# df = pd.read_csv('feb20_01-07_000000-235959.csv')

# %%
# G = nx.read_edgelist("dec_uw.tsv", create_using = nx.Graph(), nodetype=int)

# %%
print(nx.info(G))

# %%
nx.draw(G, node_size=30, node_color='g', edge_color='r')

# %%
nx.draw_random(G, node_size=20, node_color='g', edge_color='r')

# %%
nx.draw_circular(G)

# %%
nx.draw_spectral(G)

# %%
nx.draw_spring(G)

# %%
pos = nx.spring_layout(G_fb) # this takes a while to run

# %%
bc_fb = nx.betweenness_centrality(G_fb, normalized=True, endpoints=True)

# %%
node_color = [20000*G_fb.degree(v) for v in G_fb]
node_size = [v*1000 for v in bc_fb.values()]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
nx.draw_networkx(G_fb, pos=pos, with_labels=False, node_color=node_color, node_size=node_size)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
nx.draw_networkx(G_fb, pos=pos, with_labels=False)

# %%
import networkx as nx
import matplotlib.pyplot as plt
g = nx.read_edgelist('./rt.txt', nodetype=int, data=(('weight',float),), create_using=nx.DiGraph())

# %%
print(g.edges(data=True))

# %%
bc_g = nx.betweenness_centrality(g, normalized=True, endpoints=True)

# %%
# node_color = [20000*g.degree(v) for v in bc_g]
node_size = [v*1000 for v in bc_g.values()]

# %%
plt.figure(figsize=(12,12))
nx.draw(g, node_color='r', edge_color='b', node_size=30)
fig1 = plt.gcf()
plt.show()
fig1.savefig('image.png')

# %%
plt.figure(figsize=(12,12))
nx.draw_spring(g, node_color='r', edge_color='b', node_size=20)
plt.savefig('img.png')
plt.show()

# %%
nx.draw(g)
plt.figure(figsize=(20,20))
plt.show()

# %%
print(g.edges(data=True))

# %%
## weighted graph

# import networkx as nx
# import matplotlib.pyplot as plt

# g = nx.read_edgelist('./test.txt', nodetype=int,
#   data=(('weight',float),), create_using=nx.DiGraph())

# print(g.edges(data=True))
# nx.draw(g)
# plt.show()

# %%
nx.draw_random(g)

# %%
nx.draw_circular(G)

# %%
df = pd.read_csv('feb20_01-07_000000-235959.csv')

# %%
df.head()

# %%
gr = nx.from_pandas_edgelist(df, source='rt_author_id', target='rt_ref_tweet_type')

# %%
type(gr)

# %%
nx.info(gr)

# %%
gr.nodes()

# %%
len(gr.nodes())

# %%
gr.edges()

# %%
len(gr.edges())

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nx.draw(gr)

# %%
nx.draw(gr, with_labels=True)

# %%
nx.draw(gr, with_labels=True, node_color='r')

# %%
nx.draw_networkx(gr)

# %%
plt.figure(figsize=(12,12))
nx.draw(gr, node_color='r', edge_color='b', node_size=20)
plt.savefig('iamg.png')
plt.show()

# %%
g1 = nx.from_pandas_edgelist(df, source='rt_author_id', target='t_author_id')

# %%
plt.figure(figsize=(12,12))
nx.draw(g1, node_color='r', edge_color='b', node_size=20)
plt.savefig('imge.png')
plt.show()

# %%
dict_degrees = dict(nx.degree(g1))
degree_vals_g1 = dict_degrees.values()
degree_vals_vtx = dict_degrees.keys()
degvals = plt.hist(degree_vals_g1, bins=100)
plt.xlabel('degree of node')
plt.ylabel('number of nodes with degree')

# %%
dict_degrees = dict(nx.degree(g))
degree_vals_g = dict_degrees.values()
degree_vals_vtx = dict_degrees.keys()
degvals = plt.hist(degree_vals_g, bins=100)
plt.xlabel('degree of node')
plt.ylabel('number of nodes with degree')

# %%
g2 = nx.read_edgelist('./rt.txt', nodetype=int, data=(('weight',float),), create_using=nx.DiGraph())
plt.figure(figsize=(12,12))
nx.draw_random(g2, node_color='r', edge_color='b', node_size=20)
plt.savefig('ia1mge.png')
plt.show()

# %%
pos = nx.spring_layout(g2)

# %%
g2 = nx.read_edgelist('./rt.txt', nodetype=int, data=(('weight',float),), create_using=nx.DiGraph())
plt.figure(figsize=(16,16))
nx.draw_networkx_nodes(g2, node_color='purple', edge_color='b', node_size=20, pos=pos)
plt.savefig('i21mge.png')
plt.show()

# %%
bc_g2 = nx.betweenness_centrality(g2, normalized=True, endpoints=True)
node_color = [20000*g2.degree(v) for v in bc_g2]
node_size = [v*1000 for v in bc_g2.values()]

# %%
plt.figure(figsize=(16,16))
nx.draw(g2,pos=pos, node_size=100, edge_color='g')
plt.savefig('imoge.png')
plt.show()

# %%
#!pip list

# %%
#!pip install matplotlib --user

# %%
df['words'] = df['t_text'].str.split(',| ')

# %%
df

# %%
df['words'] = df['words'].str.join(',')

# %%
grp = nx.from_pandas_edgelist(df, source='id', target='words')

# %%
type(grp)

# %%
pos = nx.spring_layout(grp)

# %%
plt.figure(figsize=(36,36))
nx.draw(grp,node_size=60, edge_color='g', pos=pos)
# plt.savefig('image21.png')
plt.show()

# %%
g=nx.Graph()

# %%
d = []

# %%
g.add_edges_from(d)

# %%
read_json_file('jg')

# %%
df = pd.read_csv('test_jan.csv')

# %%
grp = nx.from_pandas_edgelist(df, source='t_id', target='rt_id')

# %%
type(grp)

# %%
pos = nx.spring_layout(grp)

# %%
plt.figure(figsize=(10,10))
nx.draw(grp,node_size=60, edge_color='g', pos=pos)
# plt.savefig('image21.png')
plt.show()

# %%
dict_degrees = dict(nx.degree(grp))
degree_vals_g1 = dict_degrees.values()
degree_vals_vtx = dict_degrees.keys()
degvals = plt.hist(degree_vals_g1, bins=100)
plt.xlabel('degree of node')
plt.ylabel('number of nodes with degree')

# %%
print(nx.info(grp))

# %%
# grp.degree()

# %%
# nx.clustering(grp)

# %%
c_coef = nx.clustering(grp)
sum(c_coef.values())/grp.number_of_nodes() ## clustering oceffiient for the entire graph

# %%
sum(nx.clustering(grp).values())/grp.number_of_nodes()

# %%
t = nx.read_edgelist('./test_j.txt', nodetype=int, data=(('weight',float),), create_using=nx.DiGraph())

# %%
pos = nx.spring_layout(t)

# %%
plt.figure(figsize=(10,10))
nx.draw(t, node_size=80, edge_color='r', pos=pos)
# nx.draw(grp,node_size=60, edge_color='g', pos=pos)
# plt.savefig('image21.png')
plt.show()

# %%
plt.figure(figsize=(9,9))
nx.draw_circular(t, node_size=50, node_color='r', edge_color='b')

# %%
print(nx.info(grp))

# %%
# nx.clustering(t)
sum(nx.clustering(t).values())/t.number_of_nodes()

# %%
G = nx.read_edgelist("dec_uw_1x24.tsv", create_using = nx.Graph(), nodetype=int)

# %%
print(nx.info(G))

# %%
dict_degrees = dict(nx.degree(G))
degree_vals_g1 = dict_degrees.values()
degree_vals_vtx = dict_degrees.keys()
degvals = plt.hist(degree_vals_g1, bins=100)
plt.xlabel('degree of node')
plt.ylabel('number of nodes with degree')

# %%
nx.clustering(G)

# %%
c_coef = nx.clustering(G)
sum(c_coef.values())/G.number_of_nodes() ## clustering oceffiient for the entire graph

# %%
# plt.figure(figsize=(12,12))
# nx.draw(G, node_color='r', edge_color='b', node_size=30)
# # fig1 = plt.gcf()
# plt.show()
# # fig1.savefig('image.png')

# %%
jan_rt = nx.read_edgelist('./jan_rt.txt', nodetype=int, data=(('weight',float),), create_using=nx.DiGraph())

# %%
# bc_jan_rt = nx.betweenness_centrality(jan_rt, normalized=True, endpoints=True)

# %%
# node_color = [20000*g.degree(v) for v in bc_g]
# node_size = [v*1000 for v in bc_g.values()]

# %%
plt.figure(figsize=(20,20))
nx.draw(jan_rt, node_color='r', edge_color='b', node_size=30)
# fig1 = plt.gcf()
plt.show()
# fig1.savefig('image.png')

# %%
dict_degrees = dict(nx.degree(jan_rt))
degree_vals_g1 = dict_degrees.values()
degree_vals_vtx = dict_degrees.keys()
degvals = plt.hist(degree_vals_g1, bins=100)
plt.xlabel('degree of node')
plt.ylabel('number of nodes with degree')

# %%
feb_rt = nx.read_edgelist('./feb_rt.txt', nodetype=int, data=(('weight',float),), create_using=nx.DiGraph())

# %%
# bc_jan_rt = nx.betweenness_centrality(jan_rt, normalized=True, endpoints=True)

# %%
# node_color = [20000*g.degree(v) for v in bc_g]
# node_size = [v*1000 for v in bc_g.values()]

# %%
plt.figure(figsize=(12,12))
nx.draw(feb_rt, node_color='r', edge_color='b', node_size=30)
# fig1 = plt.gcf()
plt.show()
# fig1.savefig('image.png')

# %%
dict_degrees = dict(nx.degree(feb_rt))
degree_vals_g1 = dict_degrees.values()
degree_vals_vtx = dict_degrees.keys()
degvals = plt.hist(degree_vals_g1, bins=100)
plt.xlabel('degree of node')
plt.ylabel('number of nodes with degree')

# %%
jan_fl = nx.read_edgelist('./jan_fl.txt', nodetype=int, data=(('weight',float),), create_using=nx.DiGraph())

# %%
# bc_jan_rt = nx.betweenness_centrality(jan_rt, normalized=True, endpoints=True)

# %%
# node_color = [20000*g.degree(v) for v in bc_g]
# node_size = [v*1000 for v in bc_g.values()]

# %%
plt.figure(figsize=(12,12))
nx.draw(jan_rt, node_color='r', edge_color='b', node_size=30)
# fig1 = plt.gcf()
plt.show()
# fig1.savefig('image.png')

# %%
dict_degrees = dict(nx.degree(jan_fl))
degree_vals_g1 = dict_degrees.values()
degree_vals_vtx = dict_degrees.keys()
degvals = plt.hist(degree_vals_g1, bins=100)
plt.xlabel('degree of node')
plt.ylabel('number of nodes with degree')

# %%
feb_fl = nx.read_edgelist('./feb_fl.txt', nodetype=int, data=(('weight',float),), create_using=nx.DiGraph())

# %%
# bc_jan_rt = nx.betweenness_centrality(jan_rt, normalized=True, endpoints=True)

# %%
# node_color = [20000*g.degree(v) for v in bc_g]
# node_size = [v*1000 for v in bc_g.values()]

# %%
plt.figure(figsize=(12,12))
nx.draw_networkx(feb_rt, node_color='r', edge_color='b', node_size=30, with_labels=False)
# fig1 = plt.gcf()
plt.show()
# fig1.savefig('image.png')

# %%
dict_degrees = dict(nx.degree(feb_fl))
degree_vals_g1 = dict_degrees.values()
degree_vals_vtx = dict_degrees.keys()
degvals = plt.hist(degree_vals_g1, bins=100)
plt.xlabel('degree of node')
plt.ylabel('number of nodes with degree')

# %%
print(nx.info(feb_rt))

# %%
feb_rt.degree()

# %%
nx.clustering(feb_rt)

# %%
nx.clustering(jan_fl)

# %%
c_coef = nx.clustering(jan_rt)
sum(c_coef.values())/jan_rt.number_of_nodes() ## clustering oceffiient for the entire graph

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

df = pd.DataFrame({'number':['123','234','345'],'contactnumber':['234','345','123'],'callduration':[1,2,4]})

df

G = nx.from_pandas_edgelist(df,'number','contactnumber', edge_attr='callduration')
durations = [i['callduration'] for i in dict(G.edges).values()]
labels = [i for i in dict(G.nodes).keys()]
labels = {i:i for i in dict(G.nodes).keys()}

fig, ax = plt.subplots(figsize=(12,5))
pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos, ax = ax, labels=True)
nx.draw_networkx_edges(G, pos, width=durations, ax=ax)
_ = nx.draw_networkx_labels(G, pos, labels, ax=ax)

# %%
df

# %%
print(nx.info(G))

# %%
len(G.nodes())

# %%
len(G.edges())

# %%
# G.degree()

# %%
## weighted graph

# import networkx as nx
# import matplotlib.pyplot as plt

# g = nx.read_edgelist('./sample.txt', nodetype=int,
#   data=(('weight',float),), create_using=nx.DiGraph())

# print(g.edges(data=True))
# nx.draw(g)
# plt.show()

# %%
m_df = pd.read_csv('jan20_01-21_000000-235959.csv', encoding='utf8')
# Out:
# C:\Users\ssr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (29) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# m_df.drop_duplicates("rt_text", keep='first')
# net=m_df[['t_author_id','rt_author_id','t_rt_count']]
# net=net.dropna(subset=['t_author_id'])
# net.to_csv('net.csv', index=False, encoding='utf-8')

# %%
pd.set_option('display.max_columns', None)

# %%
# df

# %%
t_df = m_df[m_df["rt_created_at"].between('2020-01-01 00:00:00','2020-01-01 00:29:59')]
t_df[:8]
# Out:
#                   rt_created_at  rt_author_id rt_lang  \
# 5613  2020-01-01 00:29:51+00:00     383898012      en
# 5614  2020-01-01 00:29:49+00:00    2560171923      en
# 5615  2020-01-01 00:29:48+00:00    3948562637      en
# 5616  2020-01-01 00:29:47+00:00     528877193      en
# 5617  2020-01-01 00:29:47+00:00     484311140      en
# 5618  2020-01-01 00:29:44+00:00     503249817      en
# 5619  2020-01-01 00:29:43+00:00     166898394      en
# 5620  2020-01-01 00:29:40+00:00    2560171923      en
#
#                                                 rt_text                rt_id  \
# 5613  RT @ThomasKlineMD: We are witnessing an epidem...  1212169027956674560
# 5614  RT @uTobian: &amp; how much carnage Pharma wil...  1212169017269653504
# 5615  RT @JoeBiden: 2019 was a year of record violen...  1212169014841090054
# 5616  RT @tedhesson: .@KirkSemple reports that a dea...  1212169010399318017
# 5617  In 2020 I plan to be there at some point but I...  1212169009266937856
# ...

# %%
u_df = t_df.drop_duplicates("rt_text", keep='first')
u_df[:5]
# Out:
#                   rt_created_at  rt_author_id rt_lang  \
# 5613  2020-01-01 00:29:51+00:00     383898012      en
# 5614  2020-01-01 00:29:49+00:00    2560171923      en
# 5615  2020-01-01 00:29:48+00:00    3948562637      en
# 5616  2020-01-01 00:29:47+00:00     528877193      en
# 5617  2020-01-01 00:29:47+00:00     484311140      en
#
#                                                 rt_text                rt_id  \
# 5613  RT @ThomasKlineMD: We are witnessing an epidem...  1212169027956674560
# 5614  RT @uTobian: &amp; how much carnage Pharma wil...  1212169017269653504
# 5615  RT @JoeBiden: 2019 was a year of record violen...  1212169014841090054
# 5616  RT @tedhesson: .@KirkSemple reports that a dea...  1212169010399318017
# 5617  In 2020 I plan to be there at some point but I...  1212169009266937856
#
#       rt_ref_tweet_id rt_ref_tweet_type  rt_rt_count  rt_rp_count  \
# 5613     1.210788e+18     ['retweeted']          117            0
# ...

# %%
df_f = u_df[['t_author_id','rt_author_id','t_rt_count']]
df = df_f.dropna(subset=['t_author_id'])
df = df[(df != 0).all(1)]
df
# Out:
#        t_author_id        rt_author_id  t_rt_count
# 5613  2.895908e+09           383898012       117.0
# 5614  4.269862e+07          2560171923       150.0
# 5615  9.390910e+05          3948562637       930.0
# 5616  2.529486e+07           528877193        61.0
# 5617  1.911369e+09           484311140         1.0
# ...            ...                 ...         ...
# 5889  9.706549e+07          2556967117         4.0
# 5890  1.209450e+18  793194936267145216        10.0
# 5893  2.875684e+08  771289464744402944        15.0
# 5895  5.360902e+07            54886540         1.0
# 5898  1.718724e+07          2197100335         3.0
#
# [121 rows x 3 columns]

# %%
G = nx.from_pandas_edgelist(df,'t_author_id', 'rt_author_id', edge_attr='t_rt_count')

# %%
# g = nx.from_pandas_edgelist(df,'rt_id','t_id', edge_attr='rt_rt_count', create_using=nx.DiGraph())

# %%
sorted(G.degree, key=lambda x: x[1], reverse=True) ##Sort graph nodes according to their degree

# %%
list(G.nodes()) ##G.nodes()

# %%
list(G.edges())

# %%
list(nx.degree(G)) ##G.degree()

# %%
sorted(G.degree, key=lambda x: x[1], reverse=True) ##Sort graph nodes according to their degree

# %%
sorted([val for (node, val) in G.degree()],reverse = True) ##get the degrees of each node

# %%
max(dict(G.degree()).items(), key = lambda x : x[1]) ##node with max connected edges

# %%
print(nx.info(G))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 211
# Number of edges: 112
# Average in degree:   0.5308
# Average out degree:   0.5308

# %%
rt_count = [i['t_rt_count'] for i in dict(G.edges).values()]
labels = [i for i in dict(G.nodes).keys()]
labels = {i:i for i in dict(G.nodes).keys()}

# %%
fig, ax = plt.subplots(figsize=(12,8))
pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos, ax = ax, node_color='r', node_size=30)
nx.draw_networkx_edges(G, pos, ax=ax, edge_color='b')#width=rt_count,
# _ = nx.draw_networkx_labels(G, pos, labels, ax=ax)

# %%
# nx.draw(G)

# %%
# nx.draw(G, node_color='r', edge_color='b', node_size=20, pos=pos) ##spring_layout(G) ##draw(G) ##draw_random(G) ##draw_circular(G)
# plt.figure(figsize=(12,10))
# plt.show()

# %%
# G.degree()

# %%
# list(G.nodes()) ##G.nodes()

# %%
# list(G.edges())

# %%
list(nx.degree(G)) ##G.degree()

# %%
# sorted(G.degree, key=lambda x: x[1], reverse=True) ##Sort graph nodes according to their degree

# %%
# sorted([val for (node, val) in G.degree()],reverse = True) ##get the degrees of each node

# %%
# max(dict(G.degree()).items(), key = lambda x : x[1]) ##node with max connected edges

# %%
# nx.pagerank(G)

# %%
# basic usage
import community
import community as community_louvain
import networkx as nx
# G = nx.erdos_renyi_graph(100, 0.01)
# partion = community_louvain.best_partition(G)

# %%
# Relabel nodes
G = nx.relabel_nodes(G, {i: f"node_{i}" for i in G.nodes})

# Compute partition
partition = community.best_partition(G)

# Get a set of the communities
communities = set(partition.values())

# Create a dictionary mapping community number to nodes within that community
communities_dict = {c: [k for k, v in partition.items() if v == c] for c in communities}

# Filter that dictionary to map community to the node of highest degree within the community
highest_degree = {k: max(v, key=lambda x: G.degree(x)) for k, v in communities_dict.items()}

# %%
# print(partition)
# print(communities)
# print(communities_dict)
# print(highest_degree)

# %%
# nx.draw_networkx(G, with_labels=False)

# %%
# display a graph with its communities:
# as Erdos-Renyi graphs don't have true community structure,
# instead load the karate club graph
# import community as community_louvain
# import matplotlib.cm as cm
# import matplotlib.pyplot as plt
# import networkx as nx
# G = nx.karate_club_graph()
# compute the best partition
# partition = community_louvain.best_partition(G)

# %%
# # draw the graph
# pos = nx.spring_layout(G)
# # color the nodes according to their partition
# cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
# nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=40, cmap=cmap, node_color=list(partition.values()))
# nx.draw_networkx_edges(G, pos, alpha=0.5)
# plt.show()

# %%
G = nx.from_pandas_edgelist(df,'t_author_id','rt_author_id', edge_attr='t_rt_count', create_using=nx.DiGraph()) ##, create_using=nx.DiGraph() ##, create_using=nx.MultiGraph()

# %%
G = nx.from_pandas_edgelist(df,'t_author_id','rt_author_id', edge_attr='t_rt_count', create_using=nx.MultiGraph()) ##, create_using=nx.DiGraph() ##, create_using=nx.MultiGraph()

# %%
rt_count = [i['t_rt_count'] for i in dict(G.edges).values()]
# labels = [i for i in dict(G.nodes).keys()]
# labels = {i:i for i in dict(G.nodes).keys()}
labels = {e: G.edges[e]['t_rt_count'] for e in G.edges}

# %%
fig, ax = plt.subplots(figsize=(24,20))
# partition = community_louvain.best_partition(G)
# draw the graph
# pos = nx.random_layout(G) #, with_labels=False
pos = nx.spring_layout(G) # , k = 15
# pos = nx.kamada_kawai_layout(G)
# color the nodes according to their partition
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(G, pos, node_size=50, cmap=cmap, node_color=list(partition.values())) ## partition.keys(),
nx.draw_networkx_edges(G, pos, alpha=0.5, ax=ax) ##width=rt_count,
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
# nx.draw_networkx_labels(G, pos, labels, font_size=16)
plt.show()
## ['rescale_layout', 'random_layout', 'shell_layout', 'fruchterman_reingold_layout', 'spectral_layout', 'kamada_kawai_layout', 'spring_layout', 'circular_layout']

# %%
dict_degrees = dict(nx.degree(G))
degree_vals_g1 = dict_degrees.values()
degree_vals_vtx = dict_degrees.keys()
degvals = plt.hist(degree_vals_g1, bins=100)
plt.xlabel('degree of node')
plt.ylabel('number of nodes with degree')
# Out:
# Text(0, 0.5, 'number of nodes with degree')

# %%
# Compute the betweenness centrality of G: bet_cen
bet_cen = nx.betweenness_centrality(G)
# Compute the degree centrality of G: deg_cen
deg_cen = nx.degree_centrality(G)
# Compute the page rank of G: page_rank
page_rank = nx.pagerank(G)
# Compute the closeness centrality of G: clos_cen
clos_cen = nx.closeness_centrality(G)
# Compute the eigenvector centrality of G: clos_cen
eigne_cen = nx.eigenvector_centrality(G)

# %%
sorted(bet_cen.items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [(3695854095.0, 2.27842333105491e-05),
#  (2895908245.0, 0.0),
#  (383898012, 0.0),
#  (42698622.0, 0.0),
#  (2560171923, 0.0),
#  (939091.0, 0.0),
#  (3948562637, 0.0),
#  (25294855.0, 0.0),
#  (528877193, 0.0),
#  (1911368796.0, 0.0)]

# %%
sorted(deg_cen.items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [(825074418011471874, 0.014285714285714287),
#  (1.1396557615990415e+18, 0.014285714285714287),
#  (383898012, 0.009523809523809525),
#  (80857088.0, 0.009523809523809525),
#  (926972297940029442, 0.009523809523809525),
#  (3695854095.0, 0.009523809523809525),
#  (953875784.0, 0.009523809523809525),
#  (1208795851717562369, 0.009523809523809525),
#  (9.26570908667478e+17, 0.009523809523809525),
#  (793194936267145216, 0.009523809523809525)]

# %%
sorted(page_rank.items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [(953875784.0, 0.02093973723655628),
#  (7.327873927221821e+17, 0.02093973723655628),
#  (825074418011471874, 0.011289224756177923),
#  (383898012, 0.008586102182425028),
#  (926972297940029442, 0.008586102182425028),
#  (1208795851717562369, 0.008586102182425028),
#  (793194936267145216, 0.008586102182425028),
#  (1671372170, 0.008180879416347679),
#  (2560171923, 0.005882979608672134),
#  (3948562637, 0.005882979608672134)]

# %%
sorted(clos_cen.items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [(825074418011471874, 0.014285714285714285),
#  (383898012, 0.009523809523809525),
#  (926972297940029442, 0.009523809523809525),
#  (1208795851717562369, 0.009523809523809525),
#  (793194936267145216, 0.009523809523809525),
#  (1671372170, 0.006349206349206349),
#  (2560171923, 0.004761904761904762),
#  (3948562637, 0.004761904761904762),
#  (528877193, 0.004761904761904762),
#  (484311140, 0.004761904761904762)]

# %%
sorted(G.degree, key=lambda x: x[1], reverse=True)[0:10] ##Sort graph nodes according to their degree
# Out:
# [(825074418011471874, 3),
#  (1.1396557615990415e+18, 3),
#  (383898012, 2),
#  (80857088.0, 2),
#  (926972297940029442, 2),
#  (3695854095.0, 2),
#  (953875784.0, 2),
#  (1208795851717562369, 2),
#  (9.26570908667478e+17, 2),
#  (793194936267145216, 2)]

# %%
##maximum weighted edge in a networkx
sorted(G.edges(data=True),key= lambda x: x[2]['t_rt_count'],reverse=True)[:30] ## G.edges(data=True) ##access edges, including their attributes
# Out:
# [(3312011435.0, 18632964, {'t_rt_count': 6941.0}),
#  (1.0314634713369641e+18, 1171777947172139008, {'t_rt_count': 4026.0}),
#  (16190898.0, 995104454, {'t_rt_count': 3120.0}),
#  (20159596.0, 807283658973413377, {'t_rt_count': 1932.0}),
#  (26479165.0, 1093688943692832768, {'t_rt_count': 937.0}),
#  (939091.0, 3948562637, {'t_rt_count': 930.0}),
#  (20346956.0, 799233962698829824, {'t_rt_count': 575.0}),
#  (1.1777825001537085e+18, 72419082, {'t_rt_count': 526.0}),
#  (2232352123.0, 615810710, {'t_rt_count': 438.0}),
#  (22046686.0, 960646676, {'t_rt_count': 382.0}),
#  (260521052.0, 1092516085461667840, {'t_rt_count': 374.0}),
#  (1.0161595610682409e+18, 1182428061620461568, {'t_rt_count': 261.0}),
#  (403908693.0, 1172174111159795712, {'t_rt_count': 205.0}),
#  (989633635.0, 44202038, {'t_rt_count': 167.0}),
#  (42698622.0, 2560171923, {'t_rt_count': 143.0}),
#  (1.208031055040721e+18, 3102841599, {'t_rt_count': 134.0}),
# ...

# %%
list(nx.all_pairs_shortest_path(G))
# Out:
# [(2895908245.0,
#   {2895908245.0: [2895908245.0], 383898012: [2895908245.0, 383898012]}),
#  (383898012, {383898012: [383898012]}),
#  (42698622.0,
#   {42698622.0: [42698622.0], 2560171923: [42698622.0, 2560171923]}),
#  (2560171923, {2560171923: [2560171923]}),
#  (939091.0, {939091.0: [939091.0], 3948562637: [939091.0, 3948562637]}),
#  (3948562637, {3948562637: [3948562637]}),
#  (25294855.0, {25294855.0: [25294855.0], 528877193: [25294855.0, 528877193]}),
#  (528877193, {528877193: [528877193]}),
#  (1911368796.0,
#   {1911368796.0: [1911368796.0], 484311140: [1911368796.0, 484311140]}),
#  (484311140, {484311140: [484311140]}),
#  (80857088.0,
#   {80857088.0: [80857088.0],
#    503249817: [80857088.0, 503249817],
#    163438565: [80857088.0, 163438565]}),
#  (503249817, {503249817: [503249817]}),
#  (1.176168875492348e+18,
#   {1.176168875492348e+18: [1.176168875492348e+18],
#    166898394: [1.176168875492348e+18, 166898394]}),
#  (166898394, {166898394: [166898394]}),
# ...

# %%
# list(G.neighbors(1.212278243400618e+18)) ## get the common neighbors of a node

# %%
# ## find common neighbors between two sets of nodes (vertices) you can use the function
# ## https://stackoverflow.com/questions/54969732/ive-an-undirected-networkx-graph-and-want-to-find-all-neighbors-of-node-a-that
# import networkx as nx
# from itertools import chain

# G = nx.grid_graph(dim=[5, 5])

# list_A = [(20, i) for i in range(5)]
# list_B = [(16, i) for i in range(5)]
# intersec = nx.node_boundary(G, list_A) & nx.node_boundary(G, list_B)
# # {(2, 1), (2, 0), (2, 3), (2, 2), (2, 4)}

# color = []
# for i in G.nodes():
#     if i in intersec:
#         col = 'green'
#     elif i in chain(list_A, list_B):
#         col = 'red'
#     else:
#         col = 'pink'
#     color.append(col)

# %matplotlib inline
# nx.draw(G, with_labels=True, node_color=color, node_size=300)

# %%
G = nx.MultiGraph()
relations = [('A', 'B', 'neighbour'), ('A', 'B', 'friend'), ('B', 'C', 'coworker'),
             ('C', 'F', 'coworker'), ('C', 'F', 'friend'), ('F', 'G', 'coworker'),
             ('F', 'G', 'family'), ('C', 'E', 'friend'), ('E', 'D', 'family'),
             ('E', 'I', 'coworker'), ('E', 'I', 'neighbour'), ('I', 'J', 'coworker'),
             ('E', 'J', 'friend'), ('E', 'H', 'coworker')]
  
for i in relations:
    G.add_edge(i[0], i[1], relation = i[2])
      
plt.figure(figsize =(9, 9))
nx.draw_networkx(G)#, with_label = True)

# %%
import networkx as nx
G = nx.DiGraph()
G.add_edges_from([(1, 1), (1, 7), (2, 1), (2, 2), (2, 3), 
                  (2, 6), (3, 5), (4, 3), (5, 4), (5, 8),
                  (5, 9), (6, 4), (7, 2), (7, 6), (8, 7)])
  
plt.figure(figsize =(9, 9))
nx.draw_networkx(G, with_label = True, node_color ='green')

# %%
df = pd.DataFrame(
    {'source': ('a', 'a', 'a', 'b', 'c', 'd'),
     'target': ('b', 'b', 'c', 'a', 'd', 'a'),
     'weight': (1, 2, 3, 4, 5, 6)})

M = nx.from_pandas_edgelist(df, 'source', 'target', ['weight'], create_using=nx.MultiDiGraph())
# print(M.is_directed(), M.is_multigraph())
# print(M.edges(data=True))
plt.figure(figsize =(9, 9))
nx.draw_networkx(M, with_label = True, node_color ='green')

# %%
N=nx.from_pandas_edgelist(df, 'source', 'target', ['weight'], create_using=nx.DiGraph()) ##from_pandas_dataframe
plt.figure(figsize =(9, 9))
nx.draw_networkx(N, with_label = True, node_color ='green')

# %%
### TEST NETWORK

# %%
d = pd.read_csv('net500.csv', encoding='utf8')
d
# Out:
#       t_author_id  rt_author_id  t_rt_count
# 0    2.802593e+07      28967452       653.0
# 1    1.665058e+08      57283792         0.0
# 2    2.261946e+08     211845768        52.0
# 3    9.541244e+08     119321075      1912.0
# 4    9.541244e+08    1391090496      1912.0
# ..            ...           ...         ...
# 295  1.389272e+09    4417070777         3.0
# 296  2.910033e+09     587872096         9.0
# 297  2.289105e+09    3002893323         7.0
# 298  1.857900e+08     185789961         1.0
# 299  3.695854e+09      22496853       118.0
#
# [300 rows x 3 columns]

# %%
R = nx.from_pandas_edgelist(d,'t_author_id','rt_author_id', edge_attr='t_rt_count', create_using=nx.Graph()) ##, create_using=nx.DiGraph() ##, create_using=nx.MultiGraph()

# %%
rt_count = [i['t_rt_count'] for i in dict(R.edges).values()]
# labels = [i for i in dict(R.nodes).keys()]
# labels = {i:i for i in dict(R.nodes).keys()}
labels = {e: R.edges[e]['t_rt_count'] for e in R.edges}

# %%
fig, ax = plt.subplots(figsize=(60,50))
partition = community_louvain.best_partition(R)
# draw the graph
# pos = nx.draw(R)
# pos = nx.random_layout(R) #, with_labels=False
pos = nx.spring_layout(R) # , k = 15
# pos = nx.kamada_kawai_layout(G)
# color the nodes according to their partition
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(R, pos, node_size=200, cmap=cmap, node_color=list(partition.values())) ## partition.keys(),##cmap=cmap,
nx.draw_networkx_edges(R, pos, alpha=0.3, ax=ax) ##, width=rt_count) ##
nx.draw_networkx_edge_labels(R, pos, edge_labels=labels)
# nx.draw_networkx_labels(R, pos, labels, font_size=16)
fig1 = plt.gcf()
plt.show()
fig1.savefig('directed_weighted.png')
## ['rescale_layout', 'random_layout', 'shell_layout', 'fruchterman_reingold_layout', 'spectral_layout', 'kamada_kawai_layout', 'spring_layout', 'circular_layout']

# %%
import community
import collections

partition = community.best_partition(R)
values = [partition.get(node) for node in R.nodes()]
counter=collections.Counter(values)
# print(counter)

plt.subplots(figsize=(20,18))
sp = nx.spring_layout(R)
nx.draw_networkx(R, pos=sp, with_labels=False, node_size=35, node_color=values)
# plt.axes('off')
plt.title(label="Undirected Graph using RE-Tweet network", fontsize=16) ## , color="green"
fig1 = plt.gcf()
plt.show()
fig1.savefig('retweet_net_undirected.png')

# %%
R = nx.from_pandas_edgelist(d,'t_author_id','rt_author_id', edge_attr='t_rt_count', create_using=nx.MultiDiGraph())

rt_count = [i['t_rt_count'] for i in dict(R.edges).values()]
labels = {e: R.edges[e]['t_rt_count'] for e in R.edges}

fig, ax = plt.subplots(figsize=(40,30))
pos = nx.spring_layout(R) # , k = 15
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(R, pos, node_size=75, cmap=cmap, node_color=list(partition.values())) ## partition.keys(),##cmap=cmap,
nx.draw_networkx_edges(R, pos, alpha=0.5, ax=ax, width=3)
# nx.draw_networkx_edge_labels(R, pos, edge_labels=labels)
# nx.draw_networkx_labels(R, pos, labels, font_size=16)
fig1 = plt.gcf()
plt.show()
fig1.savefig('directed.png')

# %%
dict_degrees = dict(nx.degree(R))
degree_vals_g1 = dict_degrees.values()
degree_vals_vtx = dict_degrees.keys()
degvals = plt.hist(degree_vals_g1, bins=100)
plt.xlabel('degree of node')
plt.ylabel('number of nodes with degree')
# Out:
# Text(0, 0.5, 'number of nodes with degree')

# %%
import networkx.algorithms.community as nxcom
communities = sorted(nxcom.greedy_modularity_communities(R), key=len, reverse=True)
len(communities)
# Out:
# 129

# %%
##Girvan-Newman Community Detection ## https://orbifold.net/default/community-detection-using-networkx/
result = nxcom.girvan_newman(R)
communities = next(result)
len(communities)
# Out:
# 130

# %%
# Compute the betweenness centrality of G: bet_cen
bet_cen = nx.betweenness_centrality(R)
# Compute the degree centrality of G: deg_cen
deg_cen = nx.degree_centrality(R)
# Compute the page rank of G: page_rank
page_rank = nx.pagerank(R)
# Compute the closeness centrality of G: clos_cen
clos_cen = nx.closeness_centrality(R)
# Compute the eigenvector centrality of G: clos_cen
eigen_cen = nx.eigenvector_centrality(R)

print(nx.info(R))
# Out:
# Name:
# Type: Graph
# Number of nodes: 413
# Number of edges: 291
# Average degree:   1.4092

# %%
# list(nx.degree(R)) ##G.degree() ##Degree: Measures number of incoming/outgoing connections
sorted(R.degree, key=lambda x: x[1], reverse=True)[0:10] ##Sort graph nodes according to their degree
# Out:
# [(954124423.0, 72),
#  (3695854095.0, 12),
#  (8.700918610918564e+17, 9),
#  (796584061, 7),
#  (28025927.0, 6),
#  (2232352123.0, 5),
#  (1.190173547253121e+18, 5),
#  (20346956.0, 5),
#  (3012416954.0, 5),
#  (2923171916.0, 4)]

# %%
sorted(deg_cen.items(), key=lambda x:x[1], reverse=True)[0:10] ##The degree centrality of a node is simply its degree—the number of edges it has. 
## The higher the degree, the more central the node is. (i.e., the number of ties that a node has)
# Out:
# [(954124423.0, 0.17475728155339804),
#  (3695854095.0, 0.029126213592233007),
#  (8.700918610918564e+17, 0.021844660194174755),
#  (796584061, 0.01699029126213592),
#  (28025927.0, 0.014563106796116504),
#  (2232352123.0, 0.012135922330097085),
#  (1.190173547253121e+18, 0.012135922330097085),
#  (20346956.0, 0.012135922330097085),
#  (3012416954.0, 0.012135922330097085),
#  (2923171916.0, 0.009708737864077669)]

# %%
sorted(bet_cen.items(), key=lambda x:x[1], reverse=True)[0:10] ## The betweenness centrality of a node is an indicator of its centrality or importance in the network. 
## It is described as the number of shortest paths from all the vertices to all the other vertices in the network that pass through the node in consideration (Brandes 2001)
# Out:
# [(954124423.0, 0.030189214088299905),
#  (2923171916.0, 0.0011988283372310017),
#  (3012416954.0, 0.000992133796329105),
#  (1101027773206941696, 0.0009094559799683461),
#  (3695854095.0, 0.0007795336971157253),
#  (9.76016590952194e+17, 0.0006673280891975527),
#  (1203520966623662081, 0.000531500248033449),
#  (8.700918610918564e+17, 0.0004252001984267592),
#  (1.1960388657122304e+18, 0.00038976684855786264),
#  (235115427.0, 0.00038976684855786264)]

# %%
sorted(page_rank.items(), key=lambda x:x[1], reverse=True)[0:10] ## The PageRank algorithm measures the importance of each node within the graph, 
## based on the number incoming relationships and the importance of the corresponding source nodes.
# Out:
# [(954124423.0, 0.08136353139377116),
#  (3695854095.0, 0.014651792897108145),
#  (8.700918610918564e+17, 0.011316205972274989),
#  (796584061, 0.009092481355719563),
#  (28025927.0, 0.007980619047441845),
#  (2232352123.0, 0.006868756739164134),
#  (20346956.0, 0.006868756739164134),
#  (1.190173547253121e+18, 0.006467008036662167),
#  (3012416954.0, 0.005863825511288458),
#  (51552352.0, 0.0046450321226086996)]

# %%
sorted(clos_cen.items(), key=lambda x:x[1], reverse=True)[0:10] ##Closeness: Measures how quickly (minimum number of steps) can one connect to others in the network
# Out:
# [(954124423.0, 0.17475728155339806),
#  (119321075, 0.08798968022268994),
#  (1391090496, 0.08798968022268994),
#  (63065621, 0.08798968022268994),
#  (1134070120572182530, 0.08798968022268994),
#  (1203083684557066240, 0.08798968022268994),
#  (874554088096055296, 0.08798968022268994),
#  (3549678555, 0.08798968022268994),
#  (4829813404, 0.08798968022268994),
#  (862412644531163136, 0.08798968022268994)]

# %%
sorted(eigen_cen.items(), key=lambda x:x[1], reverse=True)[0:10] ## Eigenvector: Measures a trader’s connection to those who are highly connected. 
## A person with a high score will be someone who is influencing multiple players (who in turn are highly connected) and is exercising control behind the scenes.
# Out:
# [(954124423.0, 0.7070901242109955),
#  (119321075, 0.08333529633048649),
#  (1391090496, 0.08333529633048649),
#  (63065621, 0.08333529633048649),
#  (1134070120572182530, 0.08333529633048649),
#  (1203083684557066240, 0.08333529633048649),
#  (874554088096055296, 0.08333529633048649),
#  (3549678555, 0.08333529633048649),
#  (4829813404, 0.08333529633048649),
#  (862412644531163136, 0.08333529633048649)]

# %%
##maximum weighted edge in a networkx
sorted(R.edges(data=True),key= lambda x: x[2]['t_rt_count'],reverse=True)[:10] ## G.edges(data=True) ##access edges, including their attributes
# Out:
# [(20159596.0, 1694997818, {'t_rt_count': 1932.0}),
#  (954124423.0, 119321075, {'t_rt_count': 1912.0}),
#  (954124423.0, 1391090496, {'t_rt_count': 1912.0}),
#  (954124423.0, 63065621, {'t_rt_count': 1912.0}),
#  (954124423.0, 1134070120572182530, {'t_rt_count': 1912.0}),
#  (954124423.0, 1203083684557066240, {'t_rt_count': 1912.0}),
#  (954124423.0, 874554088096055296, {'t_rt_count': 1912.0}),
#  (954124423.0, 3549678555, {'t_rt_count': 1912.0}),
#  (954124423.0, 4829813404, {'t_rt_count': 1912.0}),
#  (954124423.0, 862412644531163136, {'t_rt_count': 1912.0})]

# %%
sorted(list(nx.all_pairs_shortest_path(R)))##, reverse=True
# Out:
# [(612473.0, {612473.0: [612473.0], 84448137: [612473.0, 84448137]}),
#  (939091.0,
#   {939091.0: [939091.0],
#    711917919: [939091.0, 711917919],
#    976423356810629120: [939091.0, 976423356810629120],
#    462427721: [939091.0, 462427721]}),
#  (13787352.0,
#   {13787352.0: [13787352.0],
#    934920511506616321: [13787352.0, 934920511506616321]}),
#  (14243087, {14243087: [14243087], 33179310.0: [14243087, 33179310.0]}),
#  (14454050,
#   {14454050: [14454050],
#    8.700918610918564e+17: [14454050, 8.700918610918564e+17],
#    801025143111880704: [14454050, 8.700918610918564e+17, 801025143111880704],
#    242816725: [14454050, 8.700918610918564e+17, 242816725],
#    627047442: [14454050, 8.700918610918564e+17, 627047442],
#    1013915614086193152: [14454050, 8.700918610918564e+17, 1013915614086193152],
#    4714114874: [14454050, 8.700918610918564e+17, 4714114874],
#    3125466233: [14454050, 8.700918610918564e+17, 3125466233],
# ...

# %%
list(R.neighbors(954124423)) ## get the common neighbors of a node
# Out:
# [119321075,
#  1391090496,
#  63065621,
#  1134070120572182530,
#  1203083684557066240,
#  874554088096055296,
#  3549678555,
#  4829813404,
#  862412644531163136,
#  1175051628224733185,
#  797925092680495104,
#  838873746,
#  252209020,
#  44114927,
#  785707539342254080,
#  730091440194396160,
#  1145736391948718081,
#  64753536,
#  924408025959550978,
#  4417631620,
#  981607511265554441,
#  2958717969,
#  829492467846217729,
#  3291055667,
#  2166607299,
#  53724802,
#  2193047004,
#  102409025,
#  331013345,
#  2223161112,
#  838514535875117058,
#  836442000777936896,
#  1052980960076189697,
#  260156141,
#  2377227270,
#  879348558943576064,
#  270021981,
#  159207512,
#  797055193988952064,
#  983992249934663680,
#  744512044725116928,
#  20030668,
#  556969755,
#  2193065825,
#  2294322294,
#  4857117737,
#  1722199244,
#  1048592748,
#  842155331098677249,
#  187049761,
#  865490748,
#  862243764122918912,
#  949323923136696320,
#  1260036505,
#  582501550,
#  227609949,
# ...

# %%
list(R.neighbors(3695854095)) ## get the common neighbors of a node
# Out:
# [2642358305,
#  4879934667,
#  20557070,
#  1025035972436795392,
#  1083416987169157120,
#  331672974,
#  19083538,
#  922196028861964291,
#  62232162,
#  1969201604,
#  794921695278678016,
#  22496853]

# %%
list(R.neighbors(939091)) ## get the common neighbors of a node
# Out:
# [711917919, 976423356810629120, 462427721]
